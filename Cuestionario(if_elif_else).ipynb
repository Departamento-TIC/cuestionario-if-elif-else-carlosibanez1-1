# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/cuestionario-if-elif-else-carlosibanez1-1/blob/main/Cuestionario(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 3: Créate un Cuestionario [Programar Juegos Arcade con Python y Pygame](http://programarcadegames.com/index.php)
#
#
# #Descripción
# Estas son las características que debe tener tu cuestionario:
#
#
# 1.   Créalo con cinco o más preguntas. Puedes preguntar cosas que requieran
# *   un número como respuesta (por ejemplo; ¿Cuánto es 1+1?)
# *   texto (Por ejemplo; ¿Cuál es el apellido de Harry Potter?)
# *   una selección (¿Cuál de estas opciones son las correctas A, B, o C?)
#
# 2.   Si permites que el usuario introduzca respuestas no numéricas, piensa y cubre las distintas formas en que podría contestar. Por ejemplo, si la respuesta es “a”, sería aceptable también “A”? Échale un vistazo a la Sección 3.6 para que recuerdes cómo conseguir esto.
#
# 3. Debes permitir que el usuario sepa que ha acertado con la respuesta correcta. Imprime un mensaje basado en esa respuesta.
# 4. Debes llevar la cuenta del número de respuestas acertadas.
# 5. Al final del programa, deberás mostrar el porcentaje de respuestas contestadas correctamente por el usuario.
#
# #Ejemplo de ejecución
#
# ```
# ¡A jugar!
#
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
#
# ¿Cuánto es 3*(2-1)? 3
# Correcto!
#
# ¿Cuánto es 3*2-1? 5
# Correcto!
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1. Kelly Clarkson
# 2. K.T. Tunstall
# 3. Hillary Duff
# 4. Bon Jovi
# ? 2
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 2
# No.
#
# Mis felicitaciones, has conseguido 4 respuestas correctas!
# Eso es una puntuación del 80 por ciento.
# ```

# %% [markdown]
# # Crea un celda de código debajo y escribe allí tu programa

# %%
print('¡a jugar!')
puntacion =0
libro =int(input("¿cuantos libros tiene el detective conan?"))
if libro == 110:
  print('correcto!')
  puntacion += 1
else:
  print('No.')
N =int(input("¿cuanto es 3*2-1?"))
if N == 5:
  print('correcto!')
  puntacion += 1
else:
  print('No.')
print("¿de quien es la cacion I'AM?")
print("1.Mora")
print("2.Duki")
print("3.Milo J")
print("4.Quevedo")
cantante =int(input("?"))
if cantante == 3:
  print('correcto!')
  puntacion += 1
else:
  print('No.')
print("¿cuanto es 6*2-1?")
print("1.4")
print("2.11")
print("3.6")
print("4.10")
N1 =int(input("?"))
if N1 == 2:
  print('correcto!')
  puntacion += 1
else:
  print('No.')
sea =int(input("¿cuantos cañonazos se necesitan para hacer un agujero a un barco en el sea of thieves?"))
if sea == 1:
  print('correcto!')
  puntacion += 1
else:
  print('No.')
if puntacion >= 3:
  print('felicidades, has conseguido',puntacion,'respuestas correctas!')
  print('has tenido un porcentaje de acierto del',(puntacion/5)*100,'%')
else:
  print('te parece normal, has conseguido',puntacion,'respuestas correctas')
  print('has tenido un porcentaje de acierto del',(puntacion/5)*100,'%')
# Out:
# ¡a jugar!
# ¿cuantos libros tiene el detective conan?1
# No.
# ¿cuanto es 3*2-1?2
# No.
# ¿de quien es la cacion I'AM?
# 1.Mora
# 2.Duki
# 3.Milo J
# 4.Quevedo
# ?3
# correcto!
# ¿cuanto es 6*2-1?
# 1.4
# 2.11
# 3.6
# 4.10
# ?1
# No.
# ¿cuantos cañonazos se necesitan para hacer un agujero a un barco en el sea of thieves?1
# correcto!
# te parece normal, has conseguido 2 respuestas correctas
# has tenido un porcentaje de acierto del 40.0 %
